# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Placement_Data_Full_Class.csv')
df.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %%
# seperating the categorical and numerical columns

catvars = list(df.select_dtypes(include=['object']).columns)

numvars = list(df.select_dtypes(include=['int32','int64','float32','float64']).columns)


print(catvars,numvars)
# Out:
# ['gender', 'ssc_b', 'hsc_b', 'hsc_s', 'degree_t', 'workex', 'specialisation', 'status'] ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
df.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %% [markdown]
# ### Handling Null values

# %%
df.shape
# Out:
# (215, 15)

# %%
def plotdistplot(col):
    
    plt.figure(figsize=(15,7))
    sn.distplot(df['salary'],kde=True,hist=False,label='Actual Salary',color='orange')
    sn.distplot(df[col],kde=True,hist=False,label=col,color='black')

# %%
df['salary'].value_counts()
# Out:
# salary
# 300000.0    22
# 250000.0    18
# 240000.0    15
# 260000.0     7
# 360000.0     6
# 200000.0     6
# 265000.0     6
# 220000.0     5
# 275000.0     5
# 210000.0     4
# 400000.0     4
# 270000.0     4
# 216000.0     3
# 350000.0     3
# 500000.0     3
# 252000.0     2
# 236000.0     2
# 230000.0     2
# 280000.0     2
# 218000.0     2
# 204000.0     2
# 276000.0     2
# 255000.0     1
# 285000.0     1
# 340000.0     1
# 690000.0     1
# 233000.0     1
# 290000.0     1
# 650000.0     1
# 264000.0     1
# 225000.0     1
# 940000.0     1
# 393000.0     1
# 380000.0     1
# 420000.0     1
# 425000.0     1
# 336000.0     1
# 231000.0     1
# 268000.0     1
# 450000.0     1
# 287000.0     1
# 411000.0     1
# 320000.0     1
# 278000.0     1
# 295000.0     1
# Name: count, dtype: int64

# %%
mostfreq = list(dict(df['salary'].value_counts()).items())[0]
mostfreq
# Out:
# (300000.0, 22)

# %%
df['salary'].mode()[0]
# Out:
# 300000.0

# %%
df['salary_mean'] = df['salary'].fillna(df['salary'].mean())
df['salary_median'] = df['salary'].fillna(df['salary'].median())
df['salary_mode'] = df['salary'].fillna(df['salary'].mode()[0])
df.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary  \
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0
#
#      salary_mean  salary_median  salary_mode
# 0  270000.000000       270000.0     270000.0
# 1  200000.000000       200000.0     200000.0
# 2  250000.000000       250000.0     250000.0
# 3  288655.405405       265000.0     300000.0
# 4  425000.000000       425000.0     425000.0

# %%
df.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# salary_mean        0
# salary_median      0
# salary_mode        0
# dtype: int64

# %%
df.shape
# Out:
# (215, 18)

# %%
sallist = ['salary_mean','salary_median','salary_mode']
for sal in sallist:
    plotdistplot(sal)

# %%
# filling the salary with mean

df['salary'] = df['salary'].fillna(df['salary'].mean())
df.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status         salary  \
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.000000
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.000000
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.000000
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed  288655.405405
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.000000
#
#      salary_mean  salary_median  salary_mode
# 0  270000.000000       270000.0     270000.0
# 1  200000.000000       200000.0     200000.0
# 2  250000.000000       250000.0     250000.0
# 3  288655.405405       265000.0     300000.0
# 4  425000.000000       425000.0     425000.0

# %%
df = df.drop(columns=['salary_mean', 'salary_median', 'salary_mode'],axis=1)
df.isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %% [markdown]
# ## EDA

# %%
df['status'].unique()
# Out:
# array(['Placed', 'Not Placed'], dtype=object)

# %%
sn.countplot(df['status'],palette='plasma')
# Out:
# <Axes: xlabel='salary_mode', ylabel='Density'>

# %%
def valuecount(col):
    
    return dict(df[col].value_counts())

def getcountplot(col):
    
    sn.countplot(df[col],palette='plasma')
    plt.xticks(rotation = 45,fontweight = 'bold',fontsize = '10')
    plt.yticks(rotation = 45,fontweight = 'bold',fontsize = '10')
    plt.show()
    

for col in catvars:
    print(f'Count Plot for feature {col} is shown ↓')
    getcountplot(col)
    print('='*75)
# Out:
# Count Plot for feature gender is shown ↓
# ===========================================================================
# Count Plot for feature ssc_b is shown ↓
# ===========================================================================
# Count Plot for feature hsc_b is shown ↓
# ===========================================================================
# Count Plot for feature hsc_s is shown ↓
# ===========================================================================
# Count Plot for feature degree_t is shown ↓
# ===========================================================================
# Count Plot for feature workex is shown ↓
# ===========================================================================
# Count Plot for feature specialisation is shown ↓
# ===========================================================================
# Count Plot for feature status is shown ↓
# ===========================================================================

# %%
getfinaldict = {}
for col in catvars:
    getfinaldict[col] = valuecount(col)
getfinaldict
# Out:
# {'gender': {'M': 139, 'F': 76},
#  'ssc_b': {'Central': 116, 'Others': 99},
#  'hsc_b': {'Others': 131, 'Central': 84},
#  'hsc_s': {'Commerce': 113, 'Science': 91, 'Arts': 11},
#  'degree_t': {'Comm&Mgmt': 145, 'Sci&Tech': 59, 'Others': 11},
#  'workex': {'No': 141, 'Yes': 74},
#  'specialisation': {'Mkt&Fin': 120, 'Mkt&HR': 95},
#  'status': {'Placed': 148, 'Not Placed': 67}}

# %%
# top science students placed

df[(df['degree_t']=='Sci&Tech')&(df['status']=='Placed')].sort_values(by = 'salary',ascending = False).reset_index().head(5)
# Out:
#    index  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b    hsc_s  degree_p  \
# 0    150    151      M  71.00  Central  58.66  Central  Science     58.00
# 1     77     78      M  64.00   Others  80.00   Others  Science     65.00
# 2    163    164      M  63.00   Others  67.00   Others  Science     64.00
# 3    174    175      M  73.24   Others  50.83   Others  Science     64.27
# 4     53     54      M  80.00   Others  70.00   Others  Science     72.00
#
#    degree_t workex  etest_p specialisation  mba_p  status    salary
# 0  Sci&Tech    Yes     56.0        Mkt&Fin  61.30  Placed  690000.0
# 1  Sci&Tech    Yes     69.0        Mkt&Fin  57.65  Placed  500000.0
# 2  Sci&Tech     No     75.0        Mkt&Fin  66.46  Placed  500000.0
# 3  Sci&Tech    Yes     64.0        Mkt&Fin  66.23  Placed  500000.0
# 4  Sci&Tech     No     87.0         Mkt&HR  71.04  Placed  450000.0

# %%
# top Comm&Mgt students placed

df[(df['degree_t']=='Comm&Mgmt')&(df['status']=='Placed')].sort_values(by = 'salary',ascending = False).reset_index().head(5)
# Out:
#    index  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0    119    120      M   60.8  Central   68.4  Central  Commerce      64.6
# 1    177    178      F   73.0  Central   97.0   Others  Commerce      79.0
# 2      4      5      M   85.8  Central   73.6  Central  Commerce      73.3
# 3     95     96      M   73.0  Central   78.0   Others  Commerce      65.0
# 4    210    211      M   80.6   Others   82.0   Others  Commerce      77.6
#
#     degree_t workex  etest_p specialisation  mba_p  status    salary
# 0  Comm&Mgmt    Yes    82.66        Mkt&Fin  64.34  Placed  940000.0
# 1  Comm&Mgmt    Yes    89.00        Mkt&Fin  70.81  Placed  650000.0
# 2  Comm&Mgmt     No    96.80        Mkt&Fin  55.50  Placed  425000.0
# 3  Comm&Mgmt    Yes    95.46        Mkt&Fin  62.16  Placed  420000.0
# 4  Comm&Mgmt     No    91.00        Mkt&Fin  74.49  Placed  400000.0

# %%
# max and min salary
# observation : max salary : 9,40,000 and min salary : 2,00,000

df[(df['salary']==max(df['salary'])) | (df['salary']==min(df['salary']))]
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 15      16      F  65.00  Central  75.00  Central  Commerce     69.00
# 44      45      F  77.00   Others  73.00   Others  Commerce     81.00
# 50      51      F  75.20  Central  73.20  Central   Science     68.40
# 107    108      M  82.00   Others  90.00   Others  Commerce     83.00
# 119    120      M  60.80  Central  68.40  Central  Commerce     64.60
# 135    136      F  72.00  Central  56.00   Others   Science     69.00
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# 1     Sci&Tech    Yes    86.50        Mkt&Fin  66.28  Placed  200000.0
# 15   Comm&Mgmt    Yes    72.00        Mkt&Fin  64.66  Placed  200000.0
# 44   Comm&Mgmt    Yes    89.00        Mkt&Fin  69.70  Placed  200000.0
# 50   Comm&Mgmt     No    65.00         Mkt&HR  62.98  Placed  200000.0
# 107  Comm&Mgmt     No    80.00         Mkt&HR  73.52  Placed  200000.0
# 119  Comm&Mgmt    Yes    82.66        Mkt&Fin  64.34  Placed  940000.0
# 135  Comm&Mgmt     No    55.60         Mkt&HR  65.63  Placed  200000.0

# %%
df['salary'].mean()
# Out:
# 288655.40540540544

# %%
# students with salary more than avg salary science dept

df[(df['degree_t']=='Sci&Tech')&(df['salary']>df['salary'].mean())].sort_values(by = 'salary',ascending = False).reset_index()
# Out:
#     index  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b    hsc_s  degree_p  \
# 0     150    151      M  71.00  Central  58.66  Central  Science     58.00
# 1     174    175      M  73.24   Others  50.83   Others  Science     64.27
# 2      77     78      M  64.00   Others  80.00   Others  Science     65.00
# 3     163    164      M  63.00   Others  67.00   Others  Science     64.00
# 4      53     54      M  80.00   Others  70.00   Others  Science     72.00
# 5      39     40      M  81.00   Others  68.00   Others  Science     64.00
# 6     145    146      M  89.40   Others  65.66   Others  Science     71.25
# 7     128    129      M  80.40  Central  73.40  Central  Science     77.72
# 8      22     23      F  69.80   Others  60.80   Others  Science     72.23
# 9      24     25      M  76.50   Others  97.70   Others  Science     78.86
# 10     70     71      M  82.00   Others  61.00   Others  Science     62.00
# 11    178    179      M  68.00   Others  56.00   Others  Science     68.00
# 12    153    154      M  49.00   Others  59.00   Others  Science     65.00
# 13     37     38      F  79.00  Central  76.00  Central  Science     65.60
# 14     23     24      F  77.40   Others  60.00   Others  Science     64.74
# 15    160    161      M  87.00  Central  74.00  Central  Science     65.00
# 16     83     84      M  84.00   Others  79.00   Others  Science     68.00
# 17     84     85      M  70.00  Central  63.00   Others  Science     70.00
#
#     degree_t workex  etest_p specialisation  mba_p  status    salary
# 0   Sci&Tech    Yes    56.00        Mkt&Fin  61.30  Placed  690000.0
# 1   Sci&Tech    Yes    64.00        Mkt&Fin  66.23  Placed  500000.0
# 2   Sci&Tech    Yes    69.00        Mkt&Fin  57.65  Placed  500000.0
# 3   Sci&Tech     No    75.00        Mkt&Fin  66.46  Placed  500000.0
# 4   Sci&Tech     No    87.00         Mkt&HR  71.04  Placed  450000.0
# 5   Sci&Tech     No    93.00        Mkt&Fin  62.56  Placed  411000.0
# 6   Sci&Tech     No    72.00         Mkt&HR  63.23  Placed  400000.0
# 7   Sci&Tech    Yes    81.20         Mkt&HR  76.26  Placed  400000.0
# 8   Sci&Tech     No    55.53         Mkt&HR  68.81  Placed  360000.0
# 9   Sci&Tech     No    97.40        Mkt&Fin  74.01  Placed  360000.0
# 10  Sci&Tech     No    89.00        Mkt&Fin  65.45  Placed  360000.0
# 11  Sci&Tech     No    73.00         Mkt&HR  68.07  Placed  350000.0
# 12  Sci&Tech    Yes    86.00        Mkt&Fin  62.48  Placed  340000.0
# 13  Sci&Tech     No    58.00         Mkt&HR  55.47  Placed  320000.0
# 14  Sci&Tech    Yes    92.00        Mkt&Fin  63.62  Placed  300000.0
# 15  Sci&Tech    Yes    75.00         Mkt&HR  72.29  Placed  300000.0
# 16  Sci&Tech    Yes    84.00        Mkt&Fin  66.69  Placed  300000.0
# 17  Sci&Tech    Yes    55.00        Mkt&Fin  62.00  Placed  300000.0

# %%
# students with salary more than avg salary science dept

df[(df['degree_t']=='Sci&Tech')&(df['salary']>df['salary'].mean())].sort_values(by = 'salary',ascending = False).reset_index().shape
# Out:
# (18, 16)

# %%
# students with salary more than avg salary Comm&Mgmt dept

df[(df['degree_t']=='Comm&Mgmt')&(df['salary']>df['salary'].mean())].sort_values(by = 'salary',ascending = False).reset_index()
# Out:
#     index  sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0     119    120      M  60.80  Central  68.40  Central  Commerce     64.60
# 1     177    178      F  73.00  Central  97.00   Others  Commerce     79.00
# 2       4      5      M  85.80  Central  73.60  Central  Commerce     73.30
# 3      95     96      M  73.00  Central  78.00   Others  Commerce     65.00
# 4      85     86      F  83.84   Others  89.83   Others  Commerce     77.20
# 5     210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 6      21     22      F  79.00   Others  76.00   Others  Commerce     85.00
# 7     101    102      M  63.00  Central  72.00  Central  Commerce     68.00
# 8     104    105      M  69.00  Central  63.00   Others   Science     65.00
# 9      57     58      M  68.00  Central  76.00  Central  Commerce     74.00
# 10    125    126      F  84.00  Central  73.00  Central  Commerce     73.00
# 11     28     29      M  76.76   Others  76.50   Others  Commerce     67.50
# 12     74     75      M  56.60  Central  64.80  Central  Commerce     70.20
# 13    132    133      M  67.00   Others  68.00   Others  Commerce     64.00
# 14    207    208      M  83.33  Central  78.00   Others  Commerce     61.00
# 15    200    201      M  69.00   Others  60.00   Others  Commerce     65.00
# 16     35     36      F  69.00  Central  78.00  Central  Commerce     72.00
# 17    172    173      M  73.00   Others  58.00   Others  Commerce     56.00
# 18    157    158      M  66.50  Central  62.50  Central  Commerce     60.90
# 19    147    148      M  70.00  Central  74.00  Central  Commerce     65.00
# 20    143    144      M  77.67   Others  64.89   Others  Commerce     70.67
# 21     81     82      M  81.70   Others  63.00   Others   Science     67.00
# 22     43     44      M  87.00   Others  87.00   Others  Commerce     68.00
# 23    116    117      M  68.20  Central  72.80  Central  Commerce     66.60
# 24    108    109      M  61.00  Central  82.00  Central  Commerce     69.00
# 25     16     17      M  63.00  Central  66.20  Central  Commerce     65.60
# 26    102    103      F  77.00   Others  61.00   Others  Commerce     68.00
# 27     96     97      F  76.00  Central  70.00  Central   Science     76.00
# 28     61     62      M  84.20  Central  73.40  Central  Commerce     66.89
# 29     90     91      F  85.00   Others  90.00   Others  Commerce     82.00
# 30    212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 31    171    172      M  80.00   Others  80.00   Others  Commerce     72.00
#
#      degree_t workex  etest_p specialisation  mba_p  status    salary
# 0   Comm&Mgmt    Yes    82.66        Mkt&Fin  64.34  Placed  940000.0
# 1   Comm&Mgmt    Yes    89.00        Mkt&Fin  70.81  Placed  650000.0
# 2   Comm&Mgmt     No    96.80        Mkt&Fin  55.50  Placed  425000.0
# 3   Comm&Mgmt    Yes    95.46        Mkt&Fin  62.16  Placed  420000.0
# 4   Comm&Mgmt    Yes    78.74        Mkt&Fin  76.18  Placed  400000.0
# 5   Comm&Mgmt     No    91.00        Mkt&Fin  74.49  Placed  400000.0
# 6   Comm&Mgmt     No    95.00        Mkt&Fin  69.06  Placed  393000.0
# 7   Comm&Mgmt     No    78.00         Mkt&HR  60.44  Placed  380000.0
# 8   Comm&Mgmt    Yes    55.00         Mkt&HR  58.23  Placed  360000.0
# 9   Comm&Mgmt     No    80.00        Mkt&Fin  63.59  Placed  360000.0
# 10  Comm&Mgmt     No    75.00        Mkt&Fin  73.33  Placed  350000.0
# 11  Comm&Mgmt    Yes    73.35        Mkt&Fin  64.15  Placed  350000.0
# 12  Comm&Mgmt     No    84.27        Mkt&Fin  67.20  Placed  336000.0
# 13  Comm&Mgmt    Yes    74.40         Mkt&HR  53.49  Placed  300000.0
# 14  Comm&Mgmt    Yes    88.56        Mkt&Fin  71.55  Placed  300000.0
# 15  Comm&Mgmt     No    87.55        Mkt&Fin  52.81  Placed  300000.0
# 16  Comm&Mgmt     No    71.00         Mkt&HR  62.74  Placed  300000.0
# 17  Comm&Mgmt     No    84.00         Mkt&HR  52.64  Placed  300000.0
# 18  Comm&Mgmt     No    93.40        Mkt&Fin  55.03  Placed  300000.0
# 19  Comm&Mgmt     No    83.00        Mkt&Fin  62.28  Placed  300000.0
# 20  Comm&Mgmt     No    89.00        Mkt&Fin  60.39  Placed  300000.0
# 21  Comm&Mgmt    Yes    86.00        Mkt&Fin  70.20  Placed  300000.0
# 22  Comm&Mgmt     No    95.00         Mkt&HR  62.90  Placed  300000.0
# 23  Comm&Mgmt    Yes    96.00        Mkt&Fin  70.85  Placed  300000.0
# 24  Comm&Mgmt     No    84.00        Mkt&Fin  58.31  Placed  300000.0
# 25  Comm&Mgmt    Yes    60.00        Mkt&Fin  62.54  Placed  300000.0
# 26  Comm&Mgmt    Yes    57.50        Mkt&Fin  61.31  Placed  300000.0
# 27  Comm&Mgmt    Yes    66.00        Mkt&Fin  64.44  Placed  300000.0
# 28  Comm&Mgmt     No    61.60        Mkt&Fin  62.48  Placed  300000.0
# 29  Comm&Mgmt     No    92.00        Mkt&Fin  68.03  Placed  300000.0
# 30  Comm&Mgmt    Yes    59.00        Mkt&Fin  69.72  Placed  295000.0
# 31  Comm&Mgmt    Yes    63.79        Mkt&Fin  66.04  Placed  290000.0

# %%
# students with salary more than avg salary Comm&Mgmt dept

df[(df['degree_t']=='Comm&Mgmt')&(df['salary']>df['salary'].mean())].sort_values(by = 'salary',ascending = False).reset_index().shape
# Out:
# (32, 16)

# %%
# maximum students placed are from comm&mgt

df.groupby(['degree_t'])['status'].count().plot(kind = 'bar',color = 'magenta')
# Out:
# <Axes: xlabel='degree_t'>

# %%
df['degree_t'].value_counts()
# Out:
# degree_t
# Comm&Mgmt    145
# Sci&Tech      59
# Others        11
# Name: count, dtype: int64

# %%
# Marketing and Finance specialisation are placed more

df.groupby(['specialisation'])['status'].count().plot(kind = 'bar',color = 'magenta')
# Out:
# <Axes: xlabel='specialisation'>

# %%
# females placed 35% and males 65%

df.groupby(['gender'])['status'].count().plot(kind = 'pie',autopct='%1.0f%%')
# Out:
# <Axes: xlabel='specialisation', ylabel='status'>

# %%
# max female salary ~ 6,50,000

temp = df[df['gender']=='F']
temp[temp['salary']==max(temp['salary'])].style.background_gradient(cmap = 'plasma')
# Out:
# <style type="text/css">
# #T_1f4f4_row0_col0, #T_1f4f4_row0_col2, #T_1f4f4_row0_col4, #T_1f4f4_row0_col7, #T_1f4f4_row0_col10, #T_1f4f4_row0_col12, #T_1f4f4_row0_col14 {
#   background-color: #0d0887;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1f4f4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1f4f4_level0_col0" class="col_heading level0 col0" >sl_no</th>
#       <th id="T_1f4f4_level0_col1" class="col_heading level0 col1" >gender</th>
#       <th id="T_1f4f4_level0_col2" class="col_heading level0 col2" >ssc_p</th>
#       <th id="T_1f4f4_level0_col3" class="col_heading level0 col3" >ssc_b</th>
#       <th id="T_1f4f4_level0_col4" class="col_heading level0 col4" >hsc_p</th>
#       <th id="T_1f4f4_level0_col5" class="col_heading level0 col5" >hsc_b</th>
#       <th id="T_1f4f4_level0_col6" class="col_heading level0 col6" >hsc_s</th>
#       <th id="T_1f4f4_level0_col7" class="col_heading level0 col7" >degree_p</th>
#       <th id="T_1f4f4_level0_col8" class="col_heading level0 col8" >degree_t</th>
#       <th id="T_1f4f4_level0_col9" class="col_heading level0 col9" >workex</th>
#       <th id="T_1f4f4_level0_col10" class="col_heading level0 col10" >etest_p</th>
#       <th id="T_1f4f4_level0_col11" class="col_heading level0 col11" >specialisation</th>
#       <th id="T_1f4f4_level0_col12" class="col_heading level0 col12" >mba_p</th>
#       <th id="T_1f4f4_level0_col13" class="col_heading level0 col13" >status</th>
#       <th id="T_1f4f4_level0_col14" class="col_heading level0 col14" >salary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1f4f4_level0_row0" class="row_heading level0 row0" >177</th>
#       <td id="T_1f4f4_row0_col0" class="data row0 col0" >178</td>
#       <td id="T_1f4f4_row0_col1" class="data row0 col1" >F</td>
#       <td id="T_1f4f4_row0_col2" class="data row0 col2" >73.000000</td>
#       <td id="T_1f4f4_row0_col3" class="data row0 col3" >Central</td>
#       <td id="T_1f4f4_row0_col4" class="data row0 col4" >97.000000</td>
#       <td id="T_1f4f4_row0_col5" class="data row0 col5" >Others</td>
#       <td id="T_1f4f4_row0_col6" class="data row0 col6" >Commerce</td>
#       <td id="T_1f4f4_row0_col7" class="data row0 col7" >79.000000</td>
#       <td id="T_1f4f4_row0_col8" class="data row0 col8" >Comm&Mgmt</td>
#       <td id="T_1f4f4_row0_col9" class="data row0 col9" >Yes</td>
#       <td id="T_1f4f4_row0_col10" class="data row0 col10" >89.000000</td>
#       <td id="T_1f4f4_row0_col11" class="data row0 col11" >Mkt&Fin</td>
#       <td id="T_1f4f4_row0_col12" class="data row0 col12" >70.810000</td>
#       <td id="T_1f4f4_row0_col13" class="data row0 col13" >Placed</td>
#       <td id="T_1f4f4_row0_col14" class="data row0 col14" >650000.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.groupby(['hsc_s'])['status'].count().plot(kind = 'pie',autopct='%1.0f%%',figsize=(15,7))
# Out:
# <Axes: xlabel='specialisation', ylabel='status'>

# %%
df.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status         salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.000000
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.000000
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.000000
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed  288655.405405
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.000000

# %%
getfinaldict
# Out:
# {'gender': {'M': 139, 'F': 76},
#  'ssc_b': {'Central': 116, 'Others': 99},
#  'hsc_b': {'Others': 131, 'Central': 84},
#  'hsc_s': {'Commerce': 113, 'Science': 91, 'Arts': 11},
#  'degree_t': {'Comm&Mgmt': 145, 'Sci&Tech': 59, 'Others': 11},
#  'workex': {'No': 141, 'Yes': 74},
#  'specialisation': {'Mkt&Fin': 120, 'Mkt&HR': 95},
#  'status': {'Placed': 148, 'Not Placed': 67}}

# %%
len(getfinaldict['status']),len(getfinaldict['degree_t'])
# Out:
# (2, 3)

# %%
boolcols = [key for key,value in getfinaldict.items() if len(getfinaldict[key])==2]
tripcols = [key for key in list(getfinaldict.keys()) if key not in boolcols]

print(boolcols,tripcols)
# Out:
# ['gender', 'ssc_b', 'hsc_b', 'workex', 'specialisation', 'status'] ['hsc_s', 'degree_t']

# %%
df
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status  \
# 0     Sci&Tech     No     55.0         Mkt&HR  58.80      Placed
# 1     Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed
# 2    Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed
# 3     Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed
# 4    Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed
# ..         ...    ...      ...            ...    ...         ...
# 210  Comm&Mgmt     No     91.0        Mkt&Fin  74.49      Placed
# 211   Sci&Tech     No     74.0        Mkt&Fin  53.62      Placed
# 212  Comm&Mgmt    Yes     59.0        Mkt&Fin  69.72      Placed
# 213  Comm&Mgmt     No     70.0         Mkt&HR  60.23      Placed
# 214  Comm&Mgmt     No     89.0         Mkt&HR  60.22  Not Placed
#
#             salary
# 0    270000.000000
# 1    200000.000000
# 2    250000.000000
# 3    288655.405405
# 4    425000.000000
# ..             ...
# 210  400000.000000
# 211  275000.000000
# 212  295000.000000
# 213  204000.000000
# 214  288655.405405
#
# [215 rows x 15 columns]

# %% [markdown]
# ## Label Encoding process

# %%
def labelencode(le,col):
    
    df[col] = le.fit_transform(df[col])
    
    
getmappings = {}
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for col in list(getfinaldict.keys()):
    labelencode(le,col)
    getmappings[col] = dict(zip(le.classes_,le.transform(le.classes_)))
    

df.head()
# Out:
#    sl_no  gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  \
# 0      1       1  67.00      1  91.00      1      1     58.00         2
# 1      2       1  79.33      0  78.33      1      2     77.48         2
# 2      3       1  65.00      0  68.00      0      0     64.00         0
# 3      4       1  56.00      0  52.00      0      2     52.00         2
# 4      5       1  85.80      0  73.60      0      1     73.30         0
#
#    workex  etest_p  specialisation  mba_p  status         salary
# 0       0     55.0               1  58.80       1  270000.000000
# 1       1     86.5               0  66.28       1  200000.000000
# 2       0     75.0               0  57.80       1  250000.000000
# 3       0     66.0               1  59.43       0  288655.405405
# 4       0     96.8               0  55.50       1  425000.000000

# %%
df.shape
# Out:
# (215, 15)

# %%
# this was the internal mapping structure followed by label encoder for mapping

getmappings
# Out:
# {'gender': {'F': 0, 'M': 1},
#  'ssc_b': {'Central': 0, 'Others': 1},
#  'hsc_b': {'Central': 0, 'Others': 1},
#  'hsc_s': {'Arts': 0, 'Commerce': 1, 'Science': 2},
#  'degree_t': {'Comm&Mgmt': 0, 'Others': 1, 'Sci&Tech': 2},
#  'workex': {'No': 0, 'Yes': 1},
#  'specialisation': {'Mkt&Fin': 0, 'Mkt&HR': 1},
#  'status': {'Not Placed': 0, 'Placed': 1}}

# %%
# removing unwated columns

df = df.drop(['sl_no'],axis=1)
df.head(2)
# Out:
#    gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  workex  \
# 0       1  67.00      1  91.00      1      1     58.00         2       0
# 1       1  79.33      0  78.33      1      2     77.48         2       1
#
#    etest_p  specialisation  mba_p  status    salary
# 0     55.0               1  58.80       1  270000.0
# 1     86.5               0  66.28       1  200000.0

# %% [markdown]
# ## Numerical Columns EDA

# %%
numvars[1:]
# Out:
# ['ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
import scipy.stats as stats

def getplots(df,col):
    
    plt.figure(figsize=(15,7))
    plt.subplot(1,3,1)
    plt.hist(df[col],color='magenta')
    
    plt.subplot(1,3,2)
    stats.probplot(df[col],dist='norm',plot=plt)
    
    plt.subplot(1,3,3)
    sn.boxplot(df[col],color='magenta')
    
    plt.show()
    
    
for col in numvars[1:]:
    print(f'Distribution plots for col : {col} are shown ↓')
    getplots(df,col)
    print('='*10)
# Out:
# Distribution plots for col : ssc_p are shown ↓
# ==========
# Distribution plots for col : hsc_p are shown ↓
# ==========
# Distribution plots for col : degree_p are shown ↓
# ==========
# Distribution plots for col : etest_p are shown ↓
# ==========
# Distribution plots for col : mba_p are shown ↓
# ==========
# Distribution plots for col : salary are shown ↓
# ==========

# %% [markdown]
# # Feature Selection

# %%
# checking for tightly correlated features

plt.figure(figsize=(15,7))
sn.heatmap(df.corr(),annot=True,cmap='plasma')
# Out:
# <Axes: >

# %%
'''
We will drop the salary column as well
coz after getting the placement we will get to know the salary right!

'''


data = df.copy()
test = data['status']
train = data.drop(['status','salary'],axis = 1)
train.head(2)
# Out:
#    gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  workex  \
# 0       1  67.00      1  91.00      1      1     58.00         2       0
# 1       1  79.33      0  78.33      1      2     77.48         2       1
#
#    etest_p  specialisation  mba_p
# 0     55.0               1  58.80
# 1     86.5               0  66.28

# %%
## extratrees classifier

from sklearn.ensemble import ExtraTreesClassifier
ec = ExtraTreesClassifier()
ec.fit(train,test)
# Out:
# ExtraTreesClassifier()

# %%
featbar = pd.Series(ec.feature_importances_,index=train.columns)
featbar.nlargest(7).plot(kind = 'barh')
# Out:
# <Axes: >

# %%
featbar.nlargest(7).plot(kind='pie',autopct='%1.0f%%',figsize = (15,7))
# Out:
# <Axes: >

# %%
# mutual classif

from sklearn.feature_selection import mutual_info_classif
mc = mutual_info_classif(train,test)
ax = pd.Series(mc,index=train.columns)
ax.nlargest(7).plot(kind = 'barh')
# Out:
# <Axes: >

# %%
pd.Series(mc,index=train.columns).plot(kind = 'pie',autopct='%1.0f%%',figsize = (15,7))
# Out:
# <Axes: >

# %%
'''
Selecting the top 10 contributing features in both cases
and then we will do the intersection of both the results
so that we will get atleast top 5 most contributing features!

'''

featcol = list(featbar.nlargest(10).index)
mutclasif = list(ax.nlargest(10).index)
commoncols = list(set(featcol).intersection(set(mutclasif)))
print(commoncols)
# Out:
# ['mba_p', 'hsc_s', 'ssc_p', 'workex', 'degree_p', 'ssc_b', 'specialisation', 'hsc_p']

# %%
# selecting the common cols and will do training on these cols!
# these cols were selected as a nlargest result of 2 feature selection techniques!

train = df[commoncols]
train.head()
# Out:
#    mba_p  hsc_s  ssc_p  workex  degree_p  ssc_b  specialisation  hsc_p
# 0  58.80      1  67.00       0     58.00      1               1  91.00
# 1  66.28      2  79.33       1     77.48      0               0  78.33
# 2  57.80      0  65.00       0     64.00      0               0  68.00
# 3  59.43      2  56.00       0     52.00      0               1  52.00
# 4  55.50      1  85.80       0     73.30      0               0  73.60

# %%
'''
From the above DF we notice that gender,specialisation,degree_t,workex are the 
categorical columns and they make sense isn't it?,for any placement drive
students are first filtered on basis of their boards,sem scores which in this case are {mba_p,ssc_p,degree_p,hsc_p}
and then workexperience also matters a lot!,then specialisation as well,gender is also important
because now-a-days few companies focus on women empowerment,so yes,all the features make perfect sense!

'''
getmappings
# Out:
# {'gender': {'F': 0, 'M': 1},
#  'ssc_b': {'Central': 0, 'Others': 1},
#  'hsc_b': {'Central': 0, 'Others': 1},
#  'hsc_s': {'Arts': 0, 'Commerce': 1, 'Science': 2},
#  'degree_t': {'Comm&Mgmt': 0, 'Others': 1, 'Sci&Tech': 2},
#  'workex': {'No': 0, 'Yes': 1},
#  'specialisation': {'Mkt&Fin': 0, 'Mkt&HR': 1},
#  'status': {'Not Placed': 0, 'Placed': 1}}

# %%
# renaming the cols

train = df[['gender','specialisation','degree_t','workex','ssc_p','hsc_p','degree_p','mba_p']]
train.columns = ['Gender','Specialisation','Techinal Degree','Work Experience','SSC_p','High School_p','Degree_p','MBA_p']
train.head()
# Out:
#    Gender  Specialisation  Techinal Degree  Work Experience  SSC_p  \
# 0       1               1                2                0  67.00
# 1       1               0                2                1  79.33
# 2       1               0                0                0  65.00
# 3       1               1                2                0  56.00
# 4       1               0                0                0  85.80
#
#    High School_p  Degree_p  MBA_p
# 0          91.00     58.00  58.80
# 1          78.33     77.48  66.28
# 2          68.00     64.00  57.80
# 3          52.00     52.00  59.43
# 4          73.60     73.30  55.50

# %%
train['Techinal Degree'].value_counts()
# Out:
# Techinal Degree
# 0    145
# 2     59
# 1     11
# Name: count, dtype: int64

# %% [markdown]
# ## Model Building

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import tree
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split,RandomizedSearchCV,cross_val_score
from sklearn import metrics

# %%
X_train, X_test, y_train, y_test = train_test_split(train,test,test_size=0.2)
X_train.shape,X_test.shape
# Out:
# ((172, 8), (43, 8))

# %%
dc = DecisionTreeClassifier()
dc.fit(X_train,y_train)
plt.figure(figsize=(16,9))
tree.plot_tree(dc,filled=True,class_names=['Not_placed','Placed'],feature_names=train.columns)
# Out:
# [Text(0.27848101265822783, 0.95, 'SSC_p <= 56.44\ngini = 0.426\nsamples = 172\nvalue = [53, 119]\nclass = Placed'),
#  Text(0.10126582278481013, 0.85, 'High School_p <= 62.915\ngini = 0.124\nsamples = 30\nvalue = [28, 2]\nclass = Not_placed'),
#  Text(0.18987341772151897, 0.8999999999999999, 'True  '),
#  Text(0.05063291139240506, 0.75, 'gini = 0.0\nsamples = 23\nvalue = [23, 0]\nclass = Not_placed'),
#  Text(0.1518987341772152, 0.75, 'MBA_p <= 57.55\ngini = 0.408\nsamples = 7\nvalue = [5, 2]\nclass = Not_placed'),
#  Text(0.10126582278481013, 0.65, 'Specialisation <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Placed'),
#  Text(0.05063291139240506, 0.55, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Placed'),
#  Text(0.1518987341772152, 0.55, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not_placed'),
#  Text(0.20253164556962025, 0.65, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Not_placed'),
#  Text(0.45569620253164556, 0.85, 'High School_p <= 54.5\ngini = 0.29\nsamples = 142\nvalue = [25, 117]\nclass = Placed'),
#  Text(0.36708860759493667, 0.8999999999999999, '  False'),
#  Text(0.35443037974683544, 0.75, 'SSC_p <= 71.47\ngini = 0.346\nsamples = 9\nvalue = [7, 2]\nclass = Not_placed'),
#  Text(0.3037974683544304, 0.65, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = Not_placed'),
#  Text(0.4050632911392405, 0.65, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Placed'),
#  Text(0.5569620253164557, 0.75, 'High School_p <= 70.245\ngini = 0.234\nsamples = 133\nvalue = [18, 115]\nclass = Placed'),
#  Text(0.5063291139240507, 0.65, 'MBA_p <= 59.855\ngini = 0.349\nsamples = 80\nvalue = [18, 62]\nclass = Placed'),
#  Text(0.34177215189873417, 0.55, 'SSC_p <= 59.5\ngini = 0.064\nsamples = 30\nvalue = [1, 29]\nclass = Placed'),
#  Text(0.2911392405063291, 0.45, 'High School_p <= 63.0\ngini = 0.32\nsamples = 5\nvalue = [1, 4]\nclass = Placed'),
#  Text(0.24050632911392406, 0.35, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Placed'),
#  Text(0.34177215189873417, 0.35, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Not_placed'),
#  Text(0.3924050632911392, 0.45, 'gini = 0.0\nsamples = 25\nvalue = [0, 25]\nclass = Placed'),
#  Text(0.6708860759493671, 0.55, 'SSC_p <= 69.3\ngini = 0.449\nsamples = 50\nvalue = [17, 33]\nclass = Placed'),
#  Text(0.5443037974683544, 0.45, 'Degree_p <= 67.5\ngini = 0.493\nsamples = 25\nvalue = [14.0, 11.0]\nclass = Not_placed'),
#  Text(0.4430379746835443, 0.35, 'SSC_p <= 61.4\ngini = 0.245\nsamples = 14\nvalue = [12, 2]\nclass = Not_placed'),
#  Text(0.3924050632911392, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Placed'),
#  Text(0.4936708860759494, 0.25, 'High School_p <= 66.5\ngini = 0.142\nsamples = 13\nvalue = [12, 1]\nclass = Not_placed'),
#  Text(0.4430379746835443, 0.15, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]\nclass = Not_placed'),
#  Text(0.5443037974683544, 0.15, 'SSC_p <= 63.2\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = Not_placed'),
#  Text(0.4936708860759494, 0.05, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Placed'),
#  Text(0.5949367088607594, 0.05, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Not_placed'),
#  Text(0.6455696202531646, 0.35, 'Degree_p <= 73.5\ngini = 0.298\nsamples = 11\nvalue = [2, 9]\nclass = Placed'),
#  Text(0.5949367088607594, 0.25, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]\nclass = Placed'),
#  Text(0.6962025316455697, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Not_placed'),
#  Text(0.7974683544303798, 0.45, 'MBA_p <= 66.045\ngini = 0.211\nsamples = 25\nvalue = [3, 22]\nclass = Placed'),
#  Text(0.7468354430379747, 0.35, 'gini = 0.0\nsamples = 18\nvalue = [0, 18]\nclass = Placed'),
#  Text(0.8481012658227848, 0.35, 'High School_p <= 63.08\ngini = 0.49\nsamples = 7\nvalue = [3, 4]\nclass = Placed'),
#  Text(0.7974683544303798, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Placed'),
#  Text(0.8987341772151899, 0.25, 'Gender <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = Not_placed'),
#  Text(0.8481012658227848, 0.15, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Not_placed'),
#  Text(0.9493670886075949, 0.15, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Placed'),
#  Text(0.6075949367088608, 0.65, 'gini = 0.0\nsamples = 53\nvalue = [0, 53]\nclass = Placed')]

# %%
costpath = dc.cost_complexity_pruning_path(train,test)
ccp_alpha,impurities = costpath.ccp_alphas,costpath.impurities

# %%
costpath
# Out:
# {'ccp_alphas': array([0.        , 0.00422833, 0.00422833, 0.00426357, 0.00434109,
#         0.00473435, 0.00620897, 0.00697674, 0.00826873, 0.01178068,
#         0.01185342, 0.0119541 , 0.01434505, 0.01522199, 0.01963357,
#         0.04354394, 0.14599558]),
#  'impurities': array([0.        , 0.00845666, 0.01691332, 0.02544045, 0.03412262,
#         0.04359133, 0.0684272 , 0.07540395, 0.08367268, 0.14257607,
#         0.15442948, 0.19029178, 0.20463683, 0.21985882, 0.23949239,
#         0.28303633, 0.42903191])}

# %%
len(ccp_alpha)
# Out:
# 17

# %%
modellist = []
for alpha in ccp_alpha:
    dc = DecisionTreeClassifier(ccp_alpha=alpha)
    dc.fit(X_train,y_train)
    modellist.append(dc)

# %%
modellist
# Out:
# [DecisionTreeClassifier(),
#  DecisionTreeClassifier(ccp_alpha=0.004228329809725159),
#  DecisionTreeClassifier(ccp_alpha=0.004228329809725159),
#  DecisionTreeClassifier(ccp_alpha=0.004263565891472868),
#  DecisionTreeClassifier(ccp_alpha=0.004341085271317831),
#  DecisionTreeClassifier(ccp_alpha=0.004734354320287392),
#  DecisionTreeClassifier(ccp_alpha=0.006208968510070101),
#  DecisionTreeClassifier(ccp_alpha=0.0069767441860465115),
#  DecisionTreeClassifier(ccp_alpha=0.008268733850129198),
#  DecisionTreeClassifier(ccp_alpha=0.011780676876536203),
#  DecisionTreeClassifier(ccp_alpha=0.011853417899929527),
#  DecisionTreeClassifier(ccp_alpha=0.011954099636020114),
#  DecisionTreeClassifier(ccp_alpha=0.014345049677053412),
#  DecisionTreeClassifier(ccp_alpha=0.015221987315010573),
#  DecisionTreeClassifier(ccp_alpha=0.019633565458658242),
#  DecisionTreeClassifier(ccp_alpha=0.043543939616998095),
#  DecisionTreeClassifier(ccp_alpha=0.14599558360017162)]

# %%
train_score = [clf.score(X_train,y_train) for clf in modellist]
test_score = [clf.score(X_test,y_test) for clf in modellist]

plt.xlabel('alpha_value')
plt.ylabel('accuracy')
plt.plot(ccp_alpha,train_score,label = 'train_score',marker = '+',color = 'magenta')
plt.plot(ccp_alpha,test_score,label = 'test_score',marker = '*',color = 'red')
plt.legend()
plt.show()

# %%
dc = DecisionTreeClassifier(ccp_alpha=0.0195)
dc.fit(X_train,y_train)
plt.figure(figsize=(15,7))
tree.plot_tree(dc,filled=True,class_names=['Not_placed','Placed'],feature_names=train.columns)
# Out:
# [Text(0.3333333333333333, 0.9285714285714286, 'SSC_p <= 56.44\ngini = 0.426\nsamples = 172\nvalue = [53, 119]\nclass = Placed'),
#  Text(0.16666666666666666, 0.7857142857142857, 'gini = 0.124\nsamples = 30\nvalue = [28, 2]\nclass = Not_placed'),
#  Text(0.25, 0.8571428571428572, 'True  '),
#  Text(0.5, 0.7857142857142857, 'High School_p <= 54.5\ngini = 0.29\nsamples = 142\nvalue = [25, 117]\nclass = Placed'),
#  Text(0.41666666666666663, 0.8571428571428572, '  False'),
#  Text(0.3333333333333333, 0.6428571428571429, 'gini = 0.346\nsamples = 9\nvalue = [7, 2]\nclass = Not_placed'),
#  Text(0.6666666666666666, 0.6428571428571429, 'High School_p <= 70.245\ngini = 0.234\nsamples = 133\nvalue = [18, 115]\nclass = Placed'),
#  Text(0.5, 0.5, 'MBA_p <= 59.855\ngini = 0.349\nsamples = 80\nvalue = [18, 62]\nclass = Placed'),
#  Text(0.3333333333333333, 0.35714285714285715, 'gini = 0.064\nsamples = 30\nvalue = [1, 29]\nclass = Placed'),
#  Text(0.6666666666666666, 0.35714285714285715, 'SSC_p <= 69.3\ngini = 0.449\nsamples = 50\nvalue = [17, 33]\nclass = Placed'),
#  Text(0.5, 0.21428571428571427, 'Degree_p <= 67.5\ngini = 0.493\nsamples = 25\nvalue = [14.0, 11.0]\nclass = Not_placed'),
#  Text(0.3333333333333333, 0.07142857142857142, 'gini = 0.245\nsamples = 14\nvalue = [12, 2]\nclass = Not_placed'),
#  Text(0.6666666666666666, 0.07142857142857142, 'gini = 0.298\nsamples = 11\nvalue = [2, 9]\nclass = Placed'),
#  Text(0.8333333333333334, 0.21428571428571427, 'gini = 0.211\nsamples = 25\nvalue = [3, 22]\nclass = Placed'),
#  Text(0.8333333333333334, 0.5, 'gini = 0.0\nsamples = 53\nvalue = [0, 53]\nclass = Placed')]

# %% [markdown]
# # Hyperparameter Tuning

# %%
params = {
    'RandomForest':{
        'model': RandomForestClassifier(),
        'params':{
            'n_estimators': [int(x) for x in np.linspace(start=1,stop=1200,num=10)],
            'max_depth':[int(x) for x in np.linspace(start=1,stop=30,num=5)],
            'min_samples_split':[2,5,10,12],
            'min_samples_leaf':[2,5,10,12],
            'max_features':['auto','sqrt'],
            'ccp_alpha':[0.0185,0.0190,0.0195,0.0200],
        }
    },
    
    'logistic':{
        'model':LogisticRegression(),
        'params':{
            'penalty':['l1', 'l2', 'elasticnet'],
            'C':[0.25,0.50,0.75,1.0],
            'tol':[1e-10,1e-5,1e-4,1e-3,0.025,0.25,0.50],
            'solver':['lbfgs','liblinear','saga','newton-cg'],
            'multi_class':['auto', 'ovr', 'multinomial'],
            'max_iter':[int(x) for x in np.linspace(start=1,stop=250,num=10)],
        }
    },
    'D-tree':{
        'model':DecisionTreeClassifier(),
        'params':{
            'criterion':['gini','entropy'],
            'splitter':['best','random'],
            'min_samples_split':[1,2,5,10,12],
            'min_samples_leaf':[1,2,5,10,12],
            'max_features':['auto','sqrt'],
            'ccp_alpha':[0.0185,0.0190,0.0195,0.0200],
        }
    },
    'SVM':{
        'model':SVC(),
        'params':{
            'C':[0.25,0.50,0.75,1.0],
            'tol':[1e-10,1e-5,1e-4,0.025,0.50,0.75],
            'kernel':['linear','poly','sigmoid','rbf'],
            'max_iter':[int(x) for x in np.linspace(start=1,stop=250,num=10)],
        }
    }
}

# %%
scores = []
for model_name,mp in params.items():
    
    clf = RandomizedSearchCV(mp['model'],param_distributions=mp['params'],cv=5,n_iter=10,n_jobs=-1,scoring='accuracy')
    clf.fit(X_train,y_train)
    scores.append({
        'model_name':model_name,
        'best_score':clf.best_score_,
        'best_estimator':clf.best_estimator_
    })

# %%
scores_df = pd.DataFrame(data = scores,columns = ['model_name','best_score','best_estimator'])
scores_df.head()
# Out:
#      model_name  best_score                                     best_estimator
# 0  RandomForest    0.848403  (DecisionTreeClassifier(ccp_alpha=0.0185, max_...
# 1      logistic    0.871933  LogisticRegression(max_iter=222, multi_class='...
# 2        D-tree    0.819496  DecisionTreeClassifier(ccp_alpha=0.0185, max_f...
# 3           SVM    0.860168    SVC(C=0.5, kernel='poly', max_iter=56, tol=0.5)

# %%
scores
# Out:
# [{'model_name': 'RandomForest',
#   'best_score': 0.8484033613445379,
#   'best_estimator': RandomForestClassifier(ccp_alpha=0.0185, max_depth=8, min_samples_leaf=10,
#                          min_samples_split=12, n_estimators=1066)},
#  {'model_name': 'logistic',
#   'best_score': 0.8719327731092437,
#   'best_estimator': LogisticRegression(max_iter=222, multi_class='ovr', tol=1e-05)},
#  {'model_name': 'D-tree',
#   'best_score': 0.8194957983193278,
#   'best_estimator': DecisionTreeClassifier(ccp_alpha=0.0185, max_features='sqrt',
#                          min_samples_leaf=5, min_samples_split=12)},
#  {'model_name': 'SVM',
#   'best_score': 0.8601680672268908,
#   'best_estimator': SVC(C=0.5, kernel='poly', max_iter=56, tol=0.5)}]

# %%
# random forest model


rf = RandomForestClassifier(ccp_alpha=0.019, max_depth=22, max_features='sqrt',
                         min_samples_leaf=10, min_samples_split=5,
                         n_estimators=267)
rf.fit(X_train,y_train)
y_pred = rf.predict(X_test)
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# 0.7906976744186046

# %%
# logistic regression

lr = LogisticRegression(C=0.25, max_iter=111, multi_class='ovr', solver='newton-cg',
                     tol=1e-05)

lr.fit(X_train,y_train)
y_pred = lr.predict(X_test)
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# 0.7906976744186046

# %%
# decision tree

dc = DecisionTreeClassifier(ccp_alpha=0.019, criterion='entropy',
                         max_features=None, min_samples_leaf=5,
                         min_samples_split=5, splitter='random')
dc.fit(X_train,y_train)
y_pred = dc.predict(X_test)
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# 0.8372093023255814

# %%
print(metrics.classification_report(y_test,rf.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.57      0.64        14
#            1       0.81      0.90      0.85        29
#
#     accuracy                           0.79        43
#    macro avg       0.77      0.73      0.75        43
# weighted avg       0.78      0.79      0.78        43

# %%
cn = metrics.confusion_matrix(y_test,rf.predict(X_test))
sn.heatmap(cn,annot=True,cmap='plasma')
# Out:
# <Axes: >

# %% [markdown]
# # Model Testing

# %%
traindata = np.array(train)
predicted = []
for i in range(len(traindata)):
    predicted.append(rf.predict([traindata[i]]))
    
predicted
# Out:
# [array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([0]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([0])]

# %%
resultdf = train.copy()
resultdf['Actual'] = np.array(test)
resultdf['Predicted'] = np.array(predicted)
resultdf.head()
# Out:
#    Gender  Specialisation  Techinal Degree  Work Experience  SSC_p  \
# 0       1               1                2                0  67.00
# 1       1               0                2                1  79.33
# 2       1               0                0                0  65.00
# 3       1               1                2                0  56.00
# 4       1               0                0                0  85.80
#
#    High School_p  Degree_p  MBA_p  Actual  Predicted
# 0          91.00     58.00  58.80       1          1
# 1          78.33     77.48  66.28       1          1
# 2          68.00     64.00  57.80       1          1
# 3          52.00     52.00  59.43       0          0
# 4          73.60     73.30  55.50       1          1

# %%
resultdf['Actual'].value_counts()
# Out:
# Actual
# 1    148
# 0     67
# Name: count, dtype: int64

# %%
resultdf['Predicted'].value_counts()
# Out:
# Predicted
# 1    167
# 0     48
# Name: count, dtype: int64

# %%
getmappings
# Out:
# {'gender': {'F': 0, 'M': 1},
#  'ssc_b': {'Central': 0, 'Others': 1},
#  'hsc_b': {'Central': 0, 'Others': 1},
#  'hsc_s': {'Arts': 0, 'Commerce': 1, 'Science': 2},
#  'degree_t': {'Comm&Mgmt': 0, 'Others': 1, 'Sci&Tech': 2},
#  'workex': {'No': 0, 'Yes': 1},
#  'specialisation': {'Mkt&Fin': 0, 'Mkt&HR': 1},
#  'status': {'Not Placed': 0, 'Placed': 1}}

# %% [markdown]
# ### Predicted Probability

# %%
traindata = np.array(train)
predicted = []
for i in range(len(traindata)):
    predicted.append(rf.predict_proba([traindata[i]]))
    
predicted
# Out:
# [array([[0.33688993, 0.66311007]]),
#  array([[0.08791988, 0.91208012]]),
#  array([[0.1459049, 0.8540951]]),
#  array([[0.85309813, 0.14690187]]),
#  array([[0.08688126, 0.91311874]]),
#  array([[0.57185436, 0.42814564]]),
#  array([[0.62102585, 0.37897415]]),
#  array([[0.14848425, 0.85151575]]),
#  array([[0.08837193, 0.91162807]]),
#  array([[0.35412911, 0.64587089]]),
#  array([[0.57883658, 0.42116342]]),
#  array([[0.09511546, 0.90488454]]),
#  array([[0.76617664, 0.23382336]]),
#  array([[0.210643, 0.789357]]),
#  array([[0.58098613, 0.41901387]]),
#  array([[0.10932422, 0.89067578]]),
#  array([[0.16186327, 0.83813673]]),
#  array([[0.50936375, 0.49063625]]),
#  array([[0.40629882, 0.59370118]]),
#  array([[0.16092644, 0.83907356]]),
#  array([[0.20116046, 0.79883954]]),
#  array([[0.08976397, 0.91023603]]),
#  array([[0.23670897, 0.76329103]]),
#  array([[0.19933671, 0.80066329]]),
#  array([[0.09633203, 0.90366797]]),
#  array([[0.71899565, 0.28100435]]),
#  array([[0.08986804, 0.91013196]]),
#  array([[0.18515907, 0.81484093]]),
#  array([[0.08890399, 0.91109601]]),
#  array([[0.27452099, 0.72547901]]),
#  array([[0.16738986, 0.83261014]]),
#  array([[0.53285893, 0.46714107]]),
#  array([[0.23520673, 0.76479327]]),
#  array([[0.11477464, 0.88522536]]),
#  array([[0.68172113, 0.31827887]]),
#  array([[0.14578633, 0.85421367]]),
#  array([[0.75970528, 0.24029472]]),
#  array([[0.15584374, 0.84415626]]),
#  array([[0.26344678, 0.73655322]]),
#  array([[0.16981315, 0.83018685]]),
#  array([[0.09067126, 0.90932874]]),
#  array([[0.29713144, 0.70286856]]),
#  array([[0.65050703, 0.34949297]]),
#  array([[0.12582519, 0.87417481]]),
#  array([[0.08802913, 0.91197087]]),
#  array([[0.22915777, 0.77084223]]),
#  array([[0.15903342, 0.84096658]]),
#  array([[0.27434185, 0.72565815]]),
#  array([[0.22964631, 0.77035369]]),
#  array([[0.82325363, 0.17674637]]),
#  array([[0.13538406, 0.86461594]]),
#  array([[0.76063535, 0.23936465]]),
#  array([[0.86751254, 0.13248746]]),
#  array([[0.1471073, 0.8528927]]),
#  array([[0.21597685, 0.78402315]]),
#  array([[0.24400203, 0.75599797]]),
#  array([[0.243675, 0.756325]]),
#  array([[0.09451928, 0.90548072]]),
#  array([[0.13227366, 0.86772634]]),
#  array([[0.40767336, 0.59232664]]),
#  array([[0.09363794, 0.90636206]]),
#  array([[0.09028751, 0.90971249]]),
#  array([[0.14735274, 0.85264726]]),
#  array([[0.33615554, 0.66384446]]),
#  array([[0.08701914, 0.91298086]]),
#  array([[0.82961334, 0.17038666]]),
#  array([[0.1278779, 0.8721221]]),
#  array([[0.09028751, 0.90971249]]),
#  array([[0.43496653, 0.56503347]]),
#  array([[0.09913435, 0.90086565]]),
#  array([[0.23335292, 0.76664708]]),
#  array([[0.08683881, 0.91316119]]),
#  array([[0.10494617, 0.89505383]]),
#  array([[0.11517149, 0.88482851]]),
#  array([[0.33967738, 0.66032262]]),
#  array([[0.43916844, 0.56083156]]),
#  array([[0.12393223, 0.87606777]]),
#  array([[0.1337255, 0.8662745]]),
#  array([[0.13315478, 0.86684522]]),
#  array([[0.29837705, 0.70162295]]),
#  array([[0.22085644, 0.77914356]]),
#  array([[0.14082945, 0.85917055]]),
#  array([[0.17792291, 0.82207709]]),
#  array([[0.08948591, 0.91051409]]),
#  array([[0.14433951, 0.85566049]]),
#  array([[0.08802913, 0.91197087]]),
#  array([[0.22551248, 0.77448752]]),
#  array([[0.76948458, 0.23051542]]),
#  array([[0.27921096, 0.72078904]]),
#  array([[0.1316802, 0.8683198]]),
#  array([[0.08976397, 0.91023603]]),
#  array([[0.83932494, 0.16067506]]),
#  array([[0.19190087, 0.80809913]]),
#  array([[0.67525827, 0.32474173]]),
#  array([[0.33846322, 0.66153678]]),
#  array([[0.1052166, 0.8947834]]),
#  array([[0.09840784, 0.90159216]]),
#  array([[0.26685264, 0.73314736]]),
#  array([[0.11888555, 0.88111445]]),
#  array([[0.51487148, 0.48512852]]),
#  array([[0.77373038, 0.22626962]]),
#  array([[0.19529918, 0.80470082]]),
#  array([[0.13990352, 0.86009648]]),
#  array([[0.1268486, 0.8731514]]),
#  array([[0.26357078, 0.73642922]]),
#  array([[0.51256985, 0.48743015]]),
#  array([[0.56009741, 0.43990259]]),
#  array([[0.12622956, 0.87377044]]),
#  array([[0.12421264, 0.87578736]]),
#  array([[0.54358814, 0.45641186]]),
#  array([[0.16420731, 0.83579269]]),
#  array([[0.84764231, 0.15235769]]),
#  array([[0.4875699, 0.5124301]]),
#  array([[0.09498125, 0.90501875]]),
#  array([[0.14227922, 0.85772078]]),
#  array([[0.16397497, 0.83602503]]),
#  array([[0.09466676, 0.90533324]]),
#  array([[0.09571087, 0.90428913]]),
#  array([[0.12545323, 0.87454677]]),
#  array([[0.18146738, 0.81853262]]),
#  array([[0.76168819, 0.23831181]]),
#  array([[0.19987325, 0.80012675]]),
#  array([[0.12343337, 0.87656663]]),
#  array([[0.21247389, 0.78752611]]),
#  array([[0.23438237, 0.76561763]]),
#  array([[0.08976397, 0.91023603]]),
#  array([[0.14155419, 0.85844581]]),
#  array([[0.19973709, 0.80026291]]),
#  array([[0.12406607, 0.87593393]]),
#  array([[0.09366734, 0.90633266]]),
#  array([[0.37713144, 0.62286856]]),
#  array([[0.3114199, 0.6885801]]),
#  array([[0.18806889, 0.81193111]]),
#  array([[0.18061334, 0.81938666]]),
#  array([[0.08802069, 0.91197931]]),
#  array([[0.32737814, 0.67262186]]),
#  array([[0.62940782, 0.37059218]]),
#  array([[0.26439228, 0.73560772]]),
#  array([[0.14133678, 0.85866322]]),
#  array([[0.18910077, 0.81089923]]),
#  array([[0.11343801, 0.88656199]]),
#  array([[0.45948983, 0.54051017]]),
#  array([[0.15212281, 0.84787719]]),
#  array([[0.11698998, 0.88301002]]),
#  array([[0.77407422, 0.22592578]]),
#  array([[0.17101539, 0.82898461]]),
#  array([[0.2406116, 0.7593884]]),
#  array([[0.11610416, 0.88389584]]),
#  array([[0.24361738, 0.75638262]]),
#  array([[0.73532722, 0.26467278]]),
#  array([[0.30467218, 0.69532782]]),
#  array([[0.14241769, 0.85758231]]),
#  array([[0.16322568, 0.83677432]]),
#  array([[0.53404361, 0.46595639]]),
#  array([[0.53097668, 0.46902332]]),
#  array([[0.60807292, 0.39192708]]),
#  array([[0.17991891, 0.82008109]]),
#  array([[0.25024922, 0.74975078]]),
#  array([[0.30702227, 0.69297773]]),
#  array([[0.87731476, 0.12268524]]),
#  array([[0.19408407, 0.80591593]]),
#  array([[0.86673911, 0.13326089]]),
#  array([[0.08482111, 0.91517889]]),
#  array([[0.26792489, 0.73207511]]),
#  array([[0.18283789, 0.81716211]]),
#  array([[0.14498652, 0.85501348]]),
#  array([[0.35406519, 0.64593481]]),
#  array([[0.18569805, 0.81430195]]),
#  array([[0.80795416, 0.19204584]]),
#  array([[0.72317417, 0.27682583]]),
#  array([[0.43560012, 0.56439988]]),
#  array([[0.08482111, 0.91517889]]),
#  array([[0.38835701, 0.61164299]]),
#  array([[0.86217267, 0.13782733]]),
#  array([[0.33697255, 0.66302745]]),
#  array([[0.45072382, 0.54927618]]),
#  array([[0.5382901, 0.4617099]]),
#  array([[0.08802913, 0.91197087]]),
#  array([[0.36040581, 0.63959419]]),
#  array([[0.34812409, 0.65187591]]),
#  array([[0.13681772, 0.86318228]]),
#  array([[0.48299331, 0.51700669]]),
#  array([[0.59580911, 0.40419089]]),
#  array([[0.15573197, 0.84426803]]),
#  array([[0.64887666, 0.35112334]]),
#  array([[0.14585727, 0.85414273]]),
#  array([[0.65177774, 0.34822226]]),
#  array([[0.11228249, 0.88771751]]),
#  array([[0.50456868, 0.49543132]]),
#  array([[0.41993698, 0.58006302]]),
#  array([[0.31276405, 0.68723595]]),
#  array([[0.19627696, 0.80372304]]),
#  array([[0.17747385, 0.82252615]]),
#  array([[0.39285552, 0.60714448]]),
#  array([[0.78510003, 0.21489997]]),
#  array([[0.13288051, 0.86711949]]),
#  array([[0.13514751, 0.86485249]]),
#  array([[0.38520793, 0.61479207]]),
#  array([[0.31994941, 0.68005059]]),
#  array([[0.30211228, 0.69788772]]),
#  array([[0.17279962, 0.82720038]]),
#  array([[0.71722627, 0.28277373]]),
#  array([[0.24897717, 0.75102283]]),
#  array([[0.7001887, 0.2998113]]),
#  array([[0.08802069, 0.91197931]]),
#  array([[0.19889005, 0.80110995]]),
#  array([[0.74665429, 0.25334571]]),
#  array([[0.17721549, 0.82278451]]),
#  array([[0.67077005, 0.32922995]]),
#  array([[0.13645468, 0.86354532]]),
#  array([[0.08494245, 0.91505755]]),
#  array([[0.3119199, 0.6880801]]),
#  array([[0.11510254, 0.88489746]]),
#  array([[0.34372913, 0.65627087]]),
#  array([[0.59024296, 0.40975704]])]

# %%
predicted[0][0],predicted[0][0][0],predicted[0][0][1]
# Out:
# (array([0.33688993, 0.66311007]), 0.3368899300737316, 0.6631100699262683)

# %%
resultdf['Prob_not_getting_placed'] = np.array([predicted[i][0][0] for i in range(len(predicted))])
resultdf['Prob_getting_placed'] = np.array([predicted[i][0][1] for i in range(len(predicted))])
resultdf
# Out:
#      Gender  Specialisation  Techinal Degree  Work Experience  SSC_p  \
# 0         1               1                2                0  67.00
# 1         1               0                2                1  79.33
# 2         1               0                0                0  65.00
# 3         1               1                2                0  56.00
# 4         1               0                0                0  85.80
# ..      ...             ...              ...              ...    ...
# 210       1               0                0                0  80.60
# 211       1               0                2                0  58.00
# 212       1               0                0                1  67.00
# 213       0               1                0                0  74.00
# 214       1               1                0                0  62.00
#
#      High School_p  Degree_p  MBA_p  Actual  Predicted  \
# 0            91.00     58.00  58.80       1          1
# 1            78.33     77.48  66.28       1          1
# 2            68.00     64.00  57.80       1          1
# 3            52.00     52.00  59.43       0          0
# 4            73.60     73.30  55.50       1          1
# ..             ...       ...    ...     ...        ...
# 210          82.00     77.60  74.49       1          1
# 211          60.00     72.00  53.62       1          1
# 212          67.00     73.00  69.72       1          1
# 213          66.00     58.00  60.23       1          1
# 214          58.00     53.00  60.22       0          0
#
#      Prob_not_getting_placed  Prob_getting_placed
# 0                   0.336890             0.663110
# 1                   0.087920             0.912080
# 2                   0.145905             0.854095
# 3                   0.853098             0.146902
# 4                   0.086881             0.913119
# ..                       ...                  ...
# 210                 0.084942             0.915058
# 211                 0.311920             0.688080
# 212                 0.115103             0.884897
# 213                 0.343729             0.656271
# 214                 0.590243             0.409757
#
# [215 rows x 12 columns]

# %%
# saving the model

import pickle
file = open('campusplacementpredictor.pkl','wb')
pickle.dump(rf,file)
file.close()

# %% [markdown]
# ### Conclusions
#
#
#  + 16 records were missclassified,resulting in the accuracy of 93% on testing data
#  + Random Forest model gave the best results
